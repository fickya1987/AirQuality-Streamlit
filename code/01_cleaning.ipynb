# %% [markdown]
# # Cleaning

# %% [markdown]
# ### Contents:
#  - [Import for Cleaning](#Import-for-Cleaning)
#  - [Inspecting before Cleaning](#Inspecting-before-Cleaning)
#  - [Getting similar Data](#Getting-similar-Data)
#  - [More Data](#More-Data)
#  - [Cleaning Functions](#Cleaning-Functions)
#  - [Merge Clean Data](#Merge-Clean-Data)
#  - [More Data to Import](#More-Data-to-Import)
#  - [More Data to Merge](#More-Data-to-Merge)
#  - [Putting the years together](#Putting-the-years-together)
#  - [Add Percent Change Column](#Add-Percent-Change-Column)
#  - [Rename Columns](#Rename-Columns)
#  - [Export Clean Data](#Export-Clean-Data)

# %% [markdown]
# ## Import for Cleaning
# [(back to top)](#Cleaning)
#
# Import python libraries and data to clean.
#
# Data to be cleaned includes six CSV Files with daily pollutant measures, per pollutant, per year (2017 to 2019), as well as three CSV files with High and Low temperatures observed daily for each of the same years (seven files per year). All data was observed in Cleveland, OH.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import os
import warnings
warnings.simplefilter("ignore")

# %%
os.listdir('../data/')
# Out:
# ['2017_all_cleveland_oh_CO.csv',
#  '2017_all_cleveland_oh_NO2.csv',
#  '2017_all_cleveland_oh_O3.csv',
#  '2017_all_cleveland_oh_Pb.csv',
#  '2017_all_cleveland_oh_PM10.csv',
#  '2017_all_cleveland_oh_PM2.5.csv',
#  '2017_all_cleveland_oh_SO2.csv',
#  '2018_all_cleveland_oh_CO.csv',
#  '2018_all_cleveland_oh_NO2.csv',
#  '2018_all_cleveland_oh_O3.csv',
#  '2018_all_cleveland_oh_PM10.csv',
#  '2018_all_cleveland_oh_PM2.5.csv',
#  '2018_all_cleveland_oh_SO2.csv',
#  '2019_all_cleveland_oh_CO.csv',
#  '2019_all_cleveland_oh_NO2.csv',
#  '2019_all_cleveland_oh_O3.csv',
#  '2019_all_cleveland_oh_PM10.csv',
#  '2019_all_cleveland_oh_PM2.5.csv',
#  '2019_all_cleveland_oh_SO2.csv',
#  'ClevelandOHweather2017.csv',
#  'ClevelandOHweather2018.csv',
#  'ClevelandOHweather2019.csv',
#  'combo_df.csv']

# %%
co = pd.read_csv('../data/2017_all_cleveland_oh_CO.csv')
no2 = pd.read_csv('../data/2017_all_cleveland_oh_NO2.csv')
o3 = pd.read_csv('../data/2017_all_cleveland_oh_O3.csv')
pm10 = pd.read_csv('../data/2017_all_cleveland_oh_PM10.csv')
pm25 = pd.read_csv('../data/2017_all_cleveland_oh_PM2.5.csv')
so2 = pd.read_csv('../data/2017_all_cleveland_oh_SO2.csv')

# %% [markdown]
# ## Inspecting before Cleaning
# [(back to top)](#Cleaning)
#
# Looking over tables, we found that "Site Name" __*GT Craig NCore*__ seems to have the most data. We also noticed that the device used (or "POC") for PM10 and PM2.5 that is labeled "3" has the most data, and all other pollutants have their best "POC" labelled as "1".
#
# These are our best values and what we used for our data set.

# %%
co.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1433 entries, 0 to 1432
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               1433 non-null   object
#  1   Source                             1433 non-null   object
#  2   Site ID                            1433 non-null   int64
#  3   POC                                1433 non-null   int64
#  4   Daily Max 8-hour CO Concentration  1433 non-null   float64
#  5   UNITS                              1433 non-null   object
#  6   DAILY_AQI_VALUE                    1433 non-null   int64
#  7   Site Name                          1433 non-null   object
#  8   DAILY_OBS_COUNT                    1433 non-null   int64
#  9   PERCENT_COMPLETE                   1433 non-null   float64
#  10  AQS_PARAMETER_CODE                 1433 non-null   int64
#  11  AQS_PARAMETER_DESC                 1433 non-null   object
#  12  CBSA_CODE                          1433 non-null   int64
#  13  CBSA_NAME                          1433 non-null   object
#  14  STATE_CODE                         1433 non-null   int64
#  15  STATE                              1433 non-null   object
#  16  COUNTY_CODE                        1433 non-null   int64
#  17  COUNTY                             1433 non-null   object
#  18  SITE_LATITUDE                      1433 non-null   float64
#  19  SITE_LONGITUDE                     1433 non-null   float64
# dtypes: float64(4), int64(8), object(8)
# memory usage: 224.0+ KB

# %%
co.head(2)
# Out:
#          Date Source    Site ID  POC  Daily Max 8-hour CO Concentration UNITS  \
# 0  01/01/2017    AQS  390350051    1                                0.6   ppm
# 1  01/02/2017    AQS  390350051    1                                0.8   ppm
#
#    DAILY_AQI_VALUE Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# 0                7  Galleria               19              79.0
# 1                9  Galleria               24             100.0
#
#    AQS_PARAMETER_CODE AQS_PARAMETER_DESC  CBSA_CODE             CBSA_NAME  \
# 0               42101    Carbon monoxide      17460  Cleveland-Elyria, OH
# 1               42101    Carbon monoxide      17460  Cleveland-Elyria, OH
#
#    STATE_CODE STATE  COUNTY_CODE    COUNTY  SITE_LATITUDE  SITE_LONGITUDE
# 0          39  Ohio           35  Cuyahoga      41.504605       -81.69045
# 1          39  Ohio           35  Cuyahoga      41.504605       -81.69045

# %%
no2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Date                                699 non-null    object
#  1   Source                              699 non-null    object
#  2   Site ID                             699 non-null    int64
#  3   POC                                 699 non-null    int64
#  4   Daily Max 1-hour NO2 Concentration  699 non-null    int64
#  5   UNITS                               699 non-null    object
#  6   DAILY_AQI_VALUE                     699 non-null    int64
#  7   Site Name                           699 non-null    object
#  8   DAILY_OBS_COUNT                     699 non-null    int64
#  9   PERCENT_COMPLETE                    699 non-null    float64
#  10  AQS_PARAMETER_CODE                  699 non-null    int64
#  11  AQS_PARAMETER_DESC                  699 non-null    object
#  12  CBSA_CODE                           699 non-null    int64
#  13  CBSA_NAME                           699 non-null    object
#  14  STATE_CODE                          699 non-null    int64
#  15  STATE                               699 non-null    object
#  16  COUNTY_CODE                         699 non-null    int64
#  17  COUNTY                              699 non-null    object
#  18  SITE_LATITUDE                       699 non-null    float64
#  19  SITE_LONGITUDE                      699 non-null    float64
# dtypes: float64(3), int64(9), object(8)
# memory usage: 109.3+ KB

# %%
no2.head()
# Out:
#          Date Source    Site ID  POC  Daily Max 1-hour NO2 Concentration  \
# 0  01/01/2017    AQS  390350060    1                                  36
# 1  01/02/2017    AQS  390350060    1                                  33
# 2  01/03/2017    AQS  390350060    1                                  24
# 3  01/05/2017    AQS  390350060    1                                  19
# 4  01/06/2017    AQS  390350060    1                                  25
#
#   UNITS  DAILY_AQI_VALUE       Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# 0   ppb               34  GT Craig NCore               23              96.0
# 1   ppb               31  GT Craig NCore               23              96.0
# 2   ppb               23  GT Craig NCore               21              88.0
# 3   ppb               18  GT Craig NCore               23              96.0
# 4   ppb               24  GT Craig NCore               23              96.0
#
#    AQS_PARAMETER_CODE      AQS_PARAMETER_DESC  CBSA_CODE  \
# 0               42602  Nitrogen dioxide (NO2)      17460
# 1               42602  Nitrogen dioxide (NO2)      17460
# 2               42602  Nitrogen dioxide (NO2)      17460
# 3               42602  Nitrogen dioxide (NO2)      17460
# 4               42602  Nitrogen dioxide (NO2)      17460
#
#               CBSA_NAME  STATE_CODE STATE  COUNTY_CODE    COUNTY  \
# 0  Cleveland-Elyria, OH          39  Ohio           35  Cuyahoga
# 1  Cleveland-Elyria, OH          39  Ohio           35  Cuyahoga
# 2  Cleveland-Elyria, OH          39  Ohio           35  Cuyahoga
# 3  Cleveland-Elyria, OH          39  Ohio           35  Cuyahoga
# 4  Cleveland-Elyria, OH          39  Ohio           35  Cuyahoga
#
#    SITE_LATITUDE  SITE_LONGITUDE
# 0      41.492117      -81.678449
# 1      41.492117      -81.678449
# 2      41.492117      -81.678449
# 3      41.492117      -81.678449
# 4      41.492117      -81.678449

# %%
co.shape
# Out:
# (1433, 20)

# %%
co['POC'].unique()
# Out:
# array([1], dtype=int64)

# %%
co['AQS_PARAMETER_DESC'].unique()
# Out:
# array(['Carbon monoxide'], dtype=object)

# %%
no2.shape
# Out:
# (699, 20)

# %%
no2['POC'].unique()
# Out:
# array([1], dtype=int64)

# %%
no2['AQS_PARAMETER_DESC'].unique()
# Out:
# array(['Nitrogen dioxide (NO2)'], dtype=object)

# %%
o3.shape
# Out:
# (2289, 20)

# %%
o3['POC'].unique()
# Out:
# array([1], dtype=int64)

# %%
o3['AQS_PARAMETER_DESC'].unique()
# Out:
# array(['Ozone'], dtype=object)

# %%
pm10.shape
# Out:
# (1160, 20)

# %%
pm10['POC'].unique()
# Out:
# array([1, 4, 6, 7, 8, 2, 3], dtype=int64)

# %%
pm10['AQS_PARAMETER_DESC'].unique()
# Out:
# array(['PM10 Total 0-10um STP'], dtype=object)

# %%
pm25.shape
# Out:
# (2937, 20)

# %%
pm25['POC'].unique()
# Out:
# array([1, 2, 3, 4, 5], dtype=int64)

# %%
pm25['AQS_PARAMETER_DESC'].unique()
# Out:
# array(['PM2.5 - Local Conditions',
#        'Acceptable PM2.5 AQI & Speciation Mass'], dtype=object)

# %%
so2.shape
# Out:
# (2533, 20)

# %%
so2[(so2['POC']==1) & (so2['Site Name'] == 'GT Craig NCore')].sort_values('Date').shape
# Out:
# (358, 20)

# %%
so2['POC'].unique()
# Out:
# array([2, 1], dtype=int64)

# %%
so2['AQS_PARAMETER_DESC'].unique()
# Out:
# array(['Sulfur dioxide'], dtype=object)

# %% [markdown]
# ## Getting similar Data
# [(back to top)](#Cleaning)
#
# Here we did some more exploration and extracted the relevant data: Pollutant measuremant and Daily AQI value.

# %%
co_gt1 = co[(co['POC']==1) & (co['Site Name'] == 'GT Craig NCore')].sort_values('Date')
print(co_gt1.shape)
co_gt1.head(4)
# Out:
# (341, 20)
#            Date Source    Site ID  POC  Daily Max 8-hour CO Concentration  \
# 365  01/01/2017    AQS  390350060    1                                0.5
# 366  01/02/2017    AQS  390350060    1                                0.5
# 367  01/03/2017    AQS  390350060    1                                0.4
# 368  01/04/2017    AQS  390350060    1                                0.2
#
#     UNITS  DAILY_AQI_VALUE       Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# 365   ppm                6  GT Craig NCore               18              75.0
# 366   ppm                6  GT Craig NCore               18              75.0
# 367   ppm                5  GT Craig NCore               24             100.0
# 368   ppm                2  GT Craig NCore               24             100.0
#
#      AQS_PARAMETER_CODE AQS_PARAMETER_DESC  CBSA_CODE             CBSA_NAME  \
# 365               42101    Carbon monoxide      17460  Cleveland-Elyria, OH
# 366               42101    Carbon monoxide      17460  Cleveland-Elyria, OH
# 367               42101    Carbon monoxide      17460  Cleveland-Elyria, OH
# 368               42101    Carbon monoxide      17460  Cleveland-Elyria, OH
#
#      STATE_CODE STATE  COUNTY_CODE    COUNTY  SITE_LATITUDE  SITE_LONGITUDE
# 365          39  Ohio           35  Cuyahoga      41.492117      -81.678449
# 366          39  Ohio           35  Cuyahoga      41.492117      -81.678449
# 367          39  Ohio           35  Cuyahoga      41.492117      -81.678449
# 368          39  Ohio           35  Cuyahoga      41.492117      -81.678449

# %%
no2_gt1 = no2[(no2['POC']==1) & (no2['Site Name'] == 'GT Craig NCore')].sort_values('Date')
print(no2_gt1.shape)
no2_gt1.head(4)
# Out:
# (352, 20)
#          Date Source    Site ID  POC  Daily Max 1-hour NO2 Concentration  \
# 0  01/01/2017    AQS  390350060    1                                  36
# 1  01/02/2017    AQS  390350060    1                                  33
# 2  01/03/2017    AQS  390350060    1                                  24
# 3  01/05/2017    AQS  390350060    1                                  19
#
#   UNITS  DAILY_AQI_VALUE       Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# 0   ppb               34  GT Craig NCore               23              96.0
# 1   ppb               31  GT Craig NCore               23              96.0
# 2   ppb               23  GT Craig NCore               21              88.0
# 3   ppb               18  GT Craig NCore               23              96.0
#
#    AQS_PARAMETER_CODE      AQS_PARAMETER_DESC  CBSA_CODE  \
# 0               42602  Nitrogen dioxide (NO2)      17460
# 1               42602  Nitrogen dioxide (NO2)      17460
# 2               42602  Nitrogen dioxide (NO2)      17460
# 3               42602  Nitrogen dioxide (NO2)      17460
#
#               CBSA_NAME  STATE_CODE STATE  COUNTY_CODE    COUNTY  \
# 0  Cleveland-Elyria, OH          39  Ohio           35  Cuyahoga
# 1  Cleveland-Elyria, OH          39  Ohio           35  Cuyahoga
# 2  Cleveland-Elyria, OH          39  Ohio           35  Cuyahoga
# 3  Cleveland-Elyria, OH          39  Ohio           35  Cuyahoga
#
#    SITE_LATITUDE  SITE_LONGITUDE
# 0      41.492117      -81.678449
# 1      41.492117      -81.678449
# 2      41.492117      -81.678449
# 3      41.492117      -81.678449

# %%
o3_gt1 = o3[(o3['POC']==1) & (o3['Site Name'] == 'GT Craig NCore')].sort_values('Date')
print(o3_gt1.shape)
o3_gt1.head(4)
# Out:
# (356, 20)
#            Date Source    Site ID  POC  Daily Max 8-hour Ozone Concentration  \
# 240  01/01/2017    AQS  390350060    1                                 0.026
# 241  01/02/2017    AQS  390350060    1                                 0.009
# 242  01/03/2017    AQS  390350060    1                                 0.015
# 243  01/04/2017    AQS  390350060    1                                 0.027
#
#     UNITS  DAILY_AQI_VALUE       Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# 240   ppm               24  GT Craig NCore               17             100.0
# 241   ppm                8  GT Craig NCore               17             100.0
# 242   ppm               14  GT Craig NCore               14              82.0
# 243   ppm               25  GT Craig NCore               17             100.0
#
#      AQS_PARAMETER_CODE AQS_PARAMETER_DESC  CBSA_CODE             CBSA_NAME  \
# 240               44201              Ozone      17460  Cleveland-Elyria, OH
# 241               44201              Ozone      17460  Cleveland-Elyria, OH
# 242               44201              Ozone      17460  Cleveland-Elyria, OH
# 243               44201              Ozone      17460  Cleveland-Elyria, OH
#
#      STATE_CODE STATE  COUNTY_CODE    COUNTY  SITE_LATITUDE  SITE_LONGITUDE
# 240          39  Ohio           35  Cuyahoga      41.492117      -81.678449
# 241          39  Ohio           35  Cuyahoga      41.492117      -81.678449
# 242          39  Ohio           35  Cuyahoga      41.492117      -81.678449
# 243          39  Ohio           35  Cuyahoga      41.492117      -81.678449

# %%
pm10_gt3 = pm10[(pm10['POC']==3) & (pm10['Site Name'] == 'GT Craig NCore')].sort_values('Date')
print(pm10_gt3.shape)
pm10_gt3.head(4)
# Out:
# (327, 20)
#            Date Source    Site ID  POC  Daily Mean PM10 Concentration  \
# 533  01/01/2017    AQS  390350060    3                             21
# 534  01/02/2017    AQS  390350060    3                             18
# 535  01/03/2017    AQS  390350060    3                              9
# 536  01/04/2017    AQS  390350060    3                             19
#
#         UNITS  DAILY_AQI_VALUE       Site Name  DAILY_OBS_COUNT  \
# 533  ug/m3 SC               19  GT Craig NCore                1
# 534  ug/m3 SC               17  GT Craig NCore                1
# 535  ug/m3 SC                8  GT Craig NCore                1
# 536  ug/m3 SC               18  GT Craig NCore                1
#
#      PERCENT_COMPLETE  AQS_PARAMETER_CODE     AQS_PARAMETER_DESC  CBSA_CODE  \
# 533             100.0               81102  PM10 Total 0-10um STP      17460
# 534             100.0               81102  PM10 Total 0-10um STP      17460
# 535             100.0               81102  PM10 Total 0-10um STP      17460
# 536             100.0               81102  PM10 Total 0-10um STP      17460
#
#                 CBSA_NAME  STATE_CODE STATE  COUNTY_CODE    COUNTY  \
# 533  Cleveland-Elyria, OH          39  Ohio           35  Cuyahoga
# 534  Cleveland-Elyria, OH          39  Ohio           35  Cuyahoga
# 535  Cleveland-Elyria, OH          39  Ohio           35  Cuyahoga
# 536  Cleveland-Elyria, OH          39  Ohio           35  Cuyahoga
#
#      SITE_LATITUDE  SITE_LONGITUDE
# 533      41.492117      -81.678449
# 534      41.492117      -81.678449
# 535      41.492117      -81.678449
# 536      41.492117      -81.678449

# %%
pm25_gt3 = pm25[(pm25['POC']==3) & (pm25['Site Name'] == 'GT Craig NCore')].sort_values('Date')
print(pm25_gt3.shape)
pm25_gt3.head(4)
# Out:
# (345, 20)
#            Date Source    Site ID  POC  Daily Mean PM2.5 Concentration  \
# 587  01/01/2017    AQS  390350060    3                             9.6
# 588  01/02/2017    AQS  390350060    3                            14.1
# 589  01/03/2017    AQS  390350060    3                             7.7
# 590  01/04/2017    AQS  390350060    3                             4.6
#
#         UNITS  DAILY_AQI_VALUE       Site Name  DAILY_OBS_COUNT  \
# 587  ug/m3 LC               40  GT Craig NCore                1
# 588  ug/m3 LC               55  GT Craig NCore                1
# 589  ug/m3 LC               32  GT Craig NCore                1
# 590  ug/m3 LC               19  GT Craig NCore                1
#
#      PERCENT_COMPLETE  AQS_PARAMETER_CODE  \
# 587             100.0               88502
# 588             100.0               88502
# 589             100.0               88502
# 590             100.0               88502
#
#                          AQS_PARAMETER_DESC  CBSA_CODE             CBSA_NAME  \
# 587  Acceptable PM2.5 AQI & Speciation Mass      17460  Cleveland-Elyria, OH
# 588  Acceptable PM2.5 AQI & Speciation Mass      17460  Cleveland-Elyria, OH
# 589  Acceptable PM2.5 AQI & Speciation Mass      17460  Cleveland-Elyria, OH
# 590  Acceptable PM2.5 AQI & Speciation Mass      17460  Cleveland-Elyria, OH
#
#      STATE_CODE STATE  COUNTY_CODE    COUNTY  SITE_LATITUDE  SITE_LONGITUDE
# 587          39  Ohio           35  Cuyahoga      41.492117      -81.678449
# 588          39  Ohio           35  Cuyahoga      41.492117      -81.678449
# 589          39  Ohio           35  Cuyahoga      41.492117      -81.678449
# 590          39  Ohio           35  Cuyahoga      41.492117      -81.678449

# %%
so2_gt1 = so2[(so2['POC']==1) & (so2['Site Name'] == 'GT Craig NCore')].sort_values('Date')
print(so2_gt1.shape)
so2_gt1.head(4)
# Out:
# (358, 20)
#            Date Source    Site ID  POC  Daily Max 1-hour SO2 Concentration  \
# 726  01/01/2017    AQS  390350060    1                                 5.0
# 727  01/02/2017    AQS  390350060    1                                 2.0
# 728  01/03/2017    AQS  390350060    1                                 0.0
# 729  01/04/2017    AQS  390350060    1                                 0.0
#
#     UNITS  DAILY_AQI_VALUE       Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# 726   ppb                7  GT Craig NCore               23              96.0
# 727   ppb                3  GT Craig NCore               23              96.0
# 728   ppb                0  GT Craig NCore               23              96.0
# 729   ppb                0  GT Craig NCore               23              96.0
#
#      AQS_PARAMETER_CODE AQS_PARAMETER_DESC  CBSA_CODE             CBSA_NAME  \
# 726               42401     Sulfur dioxide      17460  Cleveland-Elyria, OH
# 727               42401     Sulfur dioxide      17460  Cleveland-Elyria, OH
# 728               42401     Sulfur dioxide      17460  Cleveland-Elyria, OH
# 729               42401     Sulfur dioxide      17460  Cleveland-Elyria, OH
#
#      STATE_CODE STATE  COUNTY_CODE    COUNTY  SITE_LATITUDE  SITE_LONGITUDE
# 726          39  Ohio           35  Cuyahoga      41.492117      -81.678449
# 727          39  Ohio           35  Cuyahoga      41.492117      -81.678449
# 728          39  Ohio           35  Cuyahoga      41.492117      -81.678449
# 729          39  Ohio           35  Cuyahoga      41.492117      -81.678449

# %%
co_gt1.columns
# Out:
# Index(['Date', 'Source', 'Site ID', 'POC', 'Daily Max 8-hour CO Concentration',
#        'UNITS', 'DAILY_AQI_VALUE', 'Site Name', 'DAILY_OBS_COUNT',
#        'PERCENT_COMPLETE', 'AQS_PARAMETER_CODE', 'AQS_PARAMETER_DESC',
#        'CBSA_CODE', 'CBSA_NAME', 'STATE_CODE', 'STATE', 'COUNTY_CODE',
#        'COUNTY', 'SITE_LATITUDE', 'SITE_LONGITUDE'],
#       dtype='object')

# %% [markdown]
# # More Data
# [(back to top)](#Cleaning)
#
# After cleaning up one year's worth of data for pollutants, we decided it would be best to get more data; We pulled two more years woht of data in addition to our 2017 data (that is, we added 2018, and 2019 to our data set).
#
# The best Site and devices were consistent with the 2017 data.

# %%
co_2018 = pd.read_csv('../data/2018_all_cleveland_oh_CO.csv')
no2_2018 = pd.read_csv('../data/2018_all_cleveland_oh_NO2.csv')
o3_2018 = pd.read_csv('../data/2018_all_cleveland_oh_O3.csv')
pm10_2018 = pd.read_csv('../data/2018_all_cleveland_oh_PM10.csv')
pm25_2018 = pd.read_csv('../data/2018_all_cleveland_oh_PM2.5.csv')
so2_2018 = pd.read_csv('../data/2018_all_cleveland_oh_SO2.csv')

co_2019 = pd.read_csv('../data/2019_all_cleveland_oh_CO.csv')
no2_2019 = pd.read_csv('../data/2019_all_cleveland_oh_NO2.csv')
o3_2019 = pd.read_csv('../data/2019_all_cleveland_oh_O3.csv')
pm10_2019 = pd.read_csv('../data/2019_all_cleveland_oh_PM10.csv')
pm25_2019 = pd.read_csv('../data/2019_all_cleveland_oh_PM2.5.csv')
so2_2019 = pd.read_csv('../data/2019_all_cleveland_oh_SO2.csv')

# %%
co_gt1_2018 = co_2018[(co_2018['POC']==1) & (co_2018['Site Name'] == 'GT Craig NCore')].sort_values('Date')
print(co_gt1_2018.shape)
# Out:
# (361, 20)

# %%
no2_gt1_2018 = no2_2018[(no2_2018['POC']==1) & (no2_2018['Site Name'] == 'GT Craig NCore')].sort_values('Date')
print(no2_gt1_2018.shape)
# Out:
# (345, 20)

# %%
o3_gt1_2018 = o3_2018[(o3_2018['POC']==1) & (o3_2018['Site Name'] == 'GT Craig NCore')].sort_values('Date')
print(o3_gt1_2018.shape)
# Out:
# (350, 20)

# %%
pm10_gt3_2018 = pm10_2018[(pm10_2018['POC']==3) & (pm10_2018['Site Name'] == 'GT Craig NCore')].sort_values('Date')
print(pm10_gt3_2018.shape)
# Out:
# (363, 20)

# %%
pm25_gt3_2018 = pm25_2018[(pm25_2018['POC']==3) & (pm25_2018['Site Name'] == 'GT Craig NCore')].sort_values('Date')
print(pm25_gt3_2018.shape)
# Out:
# (290, 20)

# %%
so2_gt1_2018 = so2_2018[(so2_2018['POC']==1) & (so2_2018['Site Name'] == 'GT Craig NCore')].sort_values('Date')
print(so2_gt1_2018.shape)
# Out:
# (359, 20)

# %%
co_gt1_2019 = co_2019[(co_2019['POC']==1) & (co_2019['Site Name'] == 'GT Craig NCore')].sort_values('Date')
print(co_gt1_2019.shape)
# Out:
# (360, 20)

# %%
no2_gt1_2019 = no2_2019[(no2_2019['POC']==1) & (no2_2019['Site Name'] == 'GT Craig NCore')].sort_values('Date')
print(no2_gt1_2019.shape)
# Out:
# (341, 20)

# %%
o3_gt1_2019 = o3_2019[(o3_2019['POC']==1) & (o3_2019['Site Name'] == 'GT Craig NCore')].sort_values('Date')
print(o3_gt1_2019.shape)
# Out:
# (351, 20)

# %%
pm10_gt3_2019 = pm10_2019[(pm10_2019['POC']==3) & (pm10_2019['Site Name'] == 'GT Craig NCore')].sort_values('Date')
print(pm10_gt3_2019.shape)
# Out:
# (360, 20)

# %%
pm25_gt3_2019 = pm25_2019[(pm25_2019['POC']==3) & (pm25_2019['Site Name'] == 'GT Craig NCore')].sort_values('Date')
print(pm25_gt3_2019.shape)
# Out:
# (345, 20)

# %%
so2_gt1_2019 = so2_2019[(so2_2019['POC']==1) & (so2_2019['Site Name'] == 'GT Craig NCore')].sort_values('Date')
print(so2_gt1_2019.shape)
# Out:
# (356, 20)

# %%
no2_df = no2[['Date', 'COUNTY', 'Daily Max 1-hour NO2 Concentration', 'DAILY_AQI_VALUE']]
no2_df['date_county'] = no2_df['Date'] + ", " + no2_df['COUNTY']
no2_df.set_index('date_county', inplace=True)
no2_df.head(2)
# Out:
#                             Date    COUNTY  \
# date_county
# 01/01/2017, Cuyahoga  01/01/2017  Cuyahoga
# 01/02/2017, Cuyahoga  01/02/2017  Cuyahoga
#
#                       Daily Max 1-hour NO2 Concentration  DAILY_AQI_VALUE
# date_county
# 01/01/2017, Cuyahoga                                  36               34
# 01/02/2017, Cuyahoga                                  33               31

# %%
no2_df.drop(columns=['Date', 'COUNTY'], inplace=True)
no2_df.head()
# Out:
#                       Daily Max 1-hour NO2 Concentration  DAILY_AQI_VALUE
# date_county
# 01/01/2017, Cuyahoga                                  36               34
# 01/02/2017, Cuyahoga                                  33               31
# 01/03/2017, Cuyahoga                                  24               23
# 01/05/2017, Cuyahoga                                  19               18
# 01/06/2017, Cuyahoga                                  25               24

# %%
no2_df.isna().sum()
# Out:
# Daily Max 1-hour NO2 Concentration    0
# DAILY_AQI_VALUE                       0
# dtype: int64

# %%
no2_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 699 entries, 01/01/2017, Cuyahoga to 12/31/2017, Cuyahoga
# Data columns (total 2 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Daily Max 1-hour NO2 Concentration  699 non-null    int64
#  1   DAILY_AQI_VALUE                     699 non-null    int64
# dtypes: int64(2)
# memory usage: 16.4+ KB

# %%
no2_df2 = no2.drop(columns=['Source', 'Site ID', 'POC', 'UNITS', 'Site Name', 'AQS_PARAMETER_CODE', 'AQS_PARAMETER_DESC', 'CBSA_CODE', 'CBSA_NAME', 'STATE_CODE', 'STATE', 'COUNTY', 'COUNTY_CODE'])
no2_df2
# Out:
#            Date  Daily Max 1-hour NO2 Concentration  DAILY_AQI_VALUE  \
# 0    01/01/2017                                  36               34
# 1    01/02/2017                                  33               31
# 2    01/03/2017                                  24               23
# 3    01/05/2017                                  19               18
# 4    01/06/2017                                  25               24
# ..          ...                                 ...              ...
# 694  12/27/2017                                  29               27
# 695  12/28/2017                                  30               28
# 696  12/29/2017                                  23               22
# 697  12/30/2017                                  16               15
# 698  12/31/2017                                  29               27
#
#      DAILY_OBS_COUNT  PERCENT_COMPLETE  SITE_LATITUDE  SITE_LONGITUDE
# 0                 23              96.0      41.492117      -81.678449
# 1                 23              96.0      41.492117      -81.678449
# 2                 21              88.0      41.492117      -81.678449
# 3                 23              96.0      41.492117      -81.678449
# 4                 23              96.0      41.492117      -81.678449
# ..               ...               ...            ...             ...
# 694               24             100.0      41.440130      -81.494833
# 695               24             100.0      41.440130      -81.494833
# 696               21              88.0      41.440130      -81.494833
# 697               24             100.0      41.440130      -81.494833
# 698               24             100.0      41.440130      -81.494833
#
# [699 rows x 7 columns]

# %%
no2_df2.columns
# Out:
# Index(['Date', 'Daily Max 1-hour NO2 Concentration', 'DAILY_AQI_VALUE',
#        'DAILY_OBS_COUNT', 'PERCENT_COMPLETE', 'SITE_LATITUDE',
#        'SITE_LONGITUDE'],
#       dtype='object')

# %%
no2_df2.rename(columns={
    'Date': 'Date',
    'Daily Max 1-hour NO2 Concentration': 'no2_max',
    'DAILY_AQI_VALUE': 'aqi_val',
    'DAILY_OBS_COUNT': 'obs',
    'PERCENT_COMPLETE': 'complete',
    'SITE_LATITUDE': 'lat',
    'SITE_LONGITUDE': 'lon' 
}, inplace=True)
no2_df2
# Out:
#            Date  no2_max  aqi_val  obs  complete        lat        lon
# 0    01/01/2017       36       34   23      96.0  41.492117 -81.678449
# 1    01/02/2017       33       31   23      96.0  41.492117 -81.678449
# 2    01/03/2017       24       23   21      88.0  41.492117 -81.678449
# 3    01/05/2017       19       18   23      96.0  41.492117 -81.678449
# 4    01/06/2017       25       24   23      96.0  41.492117 -81.678449
# ..          ...      ...      ...  ...       ...        ...        ...
# 694  12/27/2017       29       27   24     100.0  41.440130 -81.494833
# 695  12/28/2017       30       28   24     100.0  41.440130 -81.494833
# 696  12/29/2017       23       22   21      88.0  41.440130 -81.494833
# 697  12/30/2017       16       15   24     100.0  41.440130 -81.494833
# 698  12/31/2017       29       27   24     100.0  41.440130 -81.494833
#
# [699 rows x 7 columns]

# %%
'Daily Max 1-hour NO2 Concentration'.split(' ')[3]
# Out:
# 'NO2'

# %%
pm25.sort_values('Date', ascending=True).head(20)
# Out:
#             Date Source    Site ID  POC  Daily Mean PM2.5 Concentration  \
# 0     01/01/2017    AQS  390350034    1                            11.8
# 352   01/01/2017    AQS  390350045    1                            11.9
# 587   01/01/2017    AQS  390350060    3                             9.6
# 120   01/01/2017    AQS  390350038    1                            12.4
# 2578  01/01/2017    AQS  391030004    3                            11.6
# 2467  01/01/2017    AQS  391030004    1                            12.1
# 1000  01/01/2017    AQS  390350065    1                            10.5
# 1270  01/01/2017    AQS  390351002    1                            12.0
# 1389  01/01/2017    AQS  390850007    1                            11.5
# 1506  01/01/2017    AQS  390850007    2                            11.2
# 1564  01/01/2017    AQS  390850007    3                             8.8
# 2102  01/01/2017    AQS  390933002    3                             5.5
# 2044  01/01/2017    AQS  390933002    2                            12.5
# 240   01/01/2017    AQS  390350038    2                            12.6
# 1929  01/01/2017    AQS  390933002    1                            12.4
# 588   01/02/2017    AQS  390350060    3                            14.1
# 1565  01/02/2017    AQS  390850007    3                             7.8
# 2103  01/02/2017    AQS  390933002    3                             6.4
# 2579  01/02/2017    AQS  391030004    3                            12.1
# 589   01/03/2017    AQS  390350060    3                             7.7
#
#          UNITS  DAILY_AQI_VALUE            Site Name  DAILY_OBS_COUNT  \
# 0     ug/m3 LC               49           District 6                1
# 352   ug/m3 LC               50  Cleveland Fire St13                1
# 587   ug/m3 LC               40       GT Craig NCore                1
# 120   ug/m3 LC               52        St Theodosius                1
# 2578  ug/m3 LC               48             Chippewa                1
# 2467  ug/m3 LC               51             Chippewa                1
# 1000  ug/m3 LC               44        Harvard Yards                1
# 1270  ug/m3 LC               50            Brookpark                1
# 1389  ug/m3 LC               48          Painesville                1
# 1506  ug/m3 LC               47          Painesville                1
# 1564  ug/m3 LC               37          Painesville                1
# 2102  ug/m3 LC               23          Barr School                1
# 2044  ug/m3 LC               52          Barr School                1
# 240   ug/m3 LC               52        St Theodosius                1
# 1929  ug/m3 LC               52          Barr School                1
# 588   ug/m3 LC               55       GT Craig NCore                1
# 1565  ug/m3 LC               33          Painesville                1
# 2103  ug/m3 LC               27          Barr School                1
# 2579  ug/m3 LC               51             Chippewa                1
# 589   ug/m3 LC               32       GT Craig NCore                1
#
#       PERCENT_COMPLETE  AQS_PARAMETER_CODE  \
# 0                100.0               88101
# 352              100.0               88101
# 587              100.0               88502
# 120              100.0               88101
# 2578             100.0               88502
# 2467             100.0               88101
# 1000             100.0               88101
# 1270             100.0               88101
# 1389             100.0               88101
# 1506             100.0               88101
# 1564             100.0               88502
# 2102             100.0               88502
# 2044             100.0               88101
# 240              100.0               88101
# 1929             100.0               88101
# 588              100.0               88502
# 1565             100.0               88502
# 2103             100.0               88502
# 2579             100.0               88502
# 589              100.0               88502
#
#                           AQS_PARAMETER_DESC  CBSA_CODE             CBSA_NAME  \
# 0                   PM2.5 - Local Conditions      17460  Cleveland-Elyria, OH
# 352                 PM2.5 - Local Conditions      17460  Cleveland-Elyria, OH
# 587   Acceptable PM2.5 AQI & Speciation Mass      17460  Cleveland-Elyria, OH
# 120                 PM2.5 - Local Conditions      17460  Cleveland-Elyria, OH
# 2578  Acceptable PM2.5 AQI & Speciation Mass      17460  Cleveland-Elyria, OH
# 2467                PM2.5 - Local Conditions      17460  Cleveland-Elyria, OH
# 1000                PM2.5 - Local Conditions      17460  Cleveland-Elyria, OH
# 1270                PM2.5 - Local Conditions      17460  Cleveland-Elyria, OH
# 1389                PM2.5 - Local Conditions      17460  Cleveland-Elyria, OH
# 1506                PM2.5 - Local Conditions      17460  Cleveland-Elyria, OH
# 1564  Acceptable PM2.5 AQI & Speciation Mass      17460  Cleveland-Elyria, OH
# 2102  Acceptable PM2.5 AQI & Speciation Mass      17460  Cleveland-Elyria, OH
# 2044                PM2.5 - Local Conditions      17460  Cleveland-Elyria, OH
# 240                 PM2.5 - Local Conditions      17460  Cleveland-Elyria, OH
# 1929                PM2.5 - Local Conditions      17460  Cleveland-Elyria, OH
# 588   Acceptable PM2.5 AQI & Speciation Mass      17460  Cleveland-Elyria, OH
# 1565  Acceptable PM2.5 AQI & Speciation Mass      17460  Cleveland-Elyria, OH
# 2103  Acceptable PM2.5 AQI & Speciation Mass      17460  Cleveland-Elyria, OH
# 2579  Acceptable PM2.5 AQI & Speciation Mass      17460  Cleveland-Elyria, OH
# 589   Acceptable PM2.5 AQI & Speciation Mass      17460  Cleveland-Elyria, OH
#
#       STATE_CODE STATE  COUNTY_CODE    COUNTY  SITE_LATITUDE  SITE_LONGITUDE
# 0             39  Ohio           35  Cuyahoga      41.555230      -81.575256
# 352           39  Ohio           35  Cuyahoga      41.471782      -81.656792
# 587           39  Ohio           35  Cuyahoga      41.492117      -81.678449
# 120           39  Ohio           35  Cuyahoga      41.477011      -81.682383
# 2578          39  Ohio          103    Medina      41.060400      -81.923900
# 2467          39  Ohio          103    Medina      41.060400      -81.923900
# 1000          39  Ohio           35  Cuyahoga      41.446624      -81.662356
# 1270          39  Ohio           35  Cuyahoga      41.396290      -81.818667
# 1389          39  Ohio           85      Lake      41.726811      -81.242156
# 1506          39  Ohio           85      Lake      41.726811      -81.242156
# 1564          39  Ohio           85      Lake      41.726811      -81.242156
# 2102          39  Ohio           93    Lorain      41.463071      -82.114261
# 2044          39  Ohio           93    Lorain      41.463071      -82.114261
# 240           39  Ohio           35  Cuyahoga      41.477011      -81.682383
# 1929          39  Ohio           93    Lorain      41.463071      -82.114261
# 588           39  Ohio           35  Cuyahoga      41.492117      -81.678449
# 1565          39  Ohio           85      Lake      41.726811      -81.242156
# 2103          39  Ohio           93    Lorain      41.463071      -82.114261
# 2579          39  Ohio          103    Medina      41.060400      -81.923900
# 589           39  Ohio           35  Cuyahoga      41.492117      -81.678449

# %%
pm10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1160 entries, 0 to 1159
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Date                           1160 non-null   object
#  1   Source                         1160 non-null   object
#  2   Site ID                        1160 non-null   int64
#  3   POC                            1160 non-null   int64
#  4   Daily Mean PM10 Concentration  1160 non-null   int64
#  5   UNITS                          1160 non-null   object
#  6   DAILY_AQI_VALUE                1160 non-null   int64
#  7   Site Name                      1160 non-null   object
#  8   DAILY_OBS_COUNT                1160 non-null   int64
#  9   PERCENT_COMPLETE               1160 non-null   float64
#  10  AQS_PARAMETER_CODE             1160 non-null   int64
#  11  AQS_PARAMETER_DESC             1160 non-null   object
#  12  CBSA_CODE                      1160 non-null   int64
#  13  CBSA_NAME                      1160 non-null   object
#  14  STATE_CODE                     1160 non-null   int64
#  15  STATE                          1160 non-null   object
#  16  COUNTY_CODE                    1160 non-null   int64
#  17  COUNTY                         1160 non-null   object
#  18  SITE_LATITUDE                  1160 non-null   float64
#  19  SITE_LONGITUDE                 1160 non-null   float64
# dtypes: float64(3), int64(9), object(8)
# memory usage: 181.4+ KB

# %%
pm10['POC'].value_counts()
# Out:
# 1    433
# 3    327
# 2    115
# 4     73
# 8     73
# 7     71
# 6     68
# Name: POC, dtype: int64

# %%
pm10.nunique()
# Out:
# Date                             365
# Source                             1
# Site ID                            7
# POC                                7
# Daily Mean PM10 Concentration     69
# UNITS                              1
# DAILY_AQI_VALUE                   59
# Site Name                          7
# DAILY_OBS_COUNT                    1
# PERCENT_COMPLETE                   1
# AQS_PARAMETER_CODE                 1
# AQS_PARAMETER_DESC                 1
# CBSA_CODE                          1
# CBSA_NAME                          1
# STATE_CODE                         1
# STATE                              1
# COUNTY_CODE                        3
# COUNTY                             3
# SITE_LATITUDE                      7
# SITE_LONGITUDE                     7
# dtype: int64

# %%
poc_mask = pm10['POC'] == 1
pm10[poc_mask]['Date'].unique()
# pm10.nunique()
# Out:
# array(['01/01/2017', '01/06/2017', '01/11/2017', '01/16/2017',
#        '01/21/2017', '01/24/2017', '01/30/2017', '02/04/2017',
#        '02/09/2017', '02/14/2017', '02/19/2017', '02/24/2017',
#        '03/01/2017', '03/06/2017', '03/11/2017', '03/16/2017',
#        '03/21/2017', '03/26/2017', '03/31/2017', '04/05/2017',
#        '04/10/2017', '04/15/2017', '04/20/2017', '04/25/2017',
#        '04/30/2017', '05/05/2017', '05/10/2017', '05/15/2017',
#        '05/20/2017', '05/25/2017', '05/30/2017', '06/04/2017',
#        '06/09/2017', '06/14/2017', '06/19/2017', '06/24/2017',
#        '06/29/2017', '07/04/2017', '07/09/2017', '07/14/2017',
#        '07/19/2017', '07/24/2017', '07/29/2017', '08/03/2017',
#        '08/08/2017', '08/13/2017', '08/18/2017', '08/23/2017',
#        '08/28/2017', '09/02/2017', '09/07/2017', '09/12/2017',
#        '09/17/2017', '09/22/2017', '09/27/2017', '10/02/2017',
#        '10/07/2017', '10/12/2017', '10/17/2017', '10/22/2017',
#        '10/27/2017', '11/01/2017', '11/06/2017', '11/11/2017',
#        '11/16/2017', '11/21/2017', '11/26/2017', '12/01/2017',
#        '12/06/2017', '12/11/2017', '12/16/2017', '12/21/2017',
#        '12/26/2017', '12/31/2017', '01/07/2017', '01/13/2017',
#        '01/19/2017', '01/25/2017', '01/31/2017', '02/06/2017',
#        '02/12/2017', '02/18/2017', '03/02/2017', '03/08/2017',
#        '03/14/2017', '03/20/2017', '04/01/2017', '04/07/2017',
#        '04/13/2017', '04/19/2017', '05/01/2017', '05/13/2017',
#        '05/19/2017', '05/31/2017', '06/06/2017', '06/12/2017',
#        '06/18/2017', '06/30/2017', '07/06/2017', '07/12/2017',
#        '07/18/2017', '07/30/2017', '08/05/2017', '08/11/2017',
#        '08/17/2017', '08/29/2017', '09/04/2017', '09/10/2017',
#        '09/16/2017', '09/28/2017', '10/04/2017', '10/10/2017',
#        '10/16/2017', '10/28/2017', '11/03/2017', '11/09/2017',
#        '11/15/2017', '11/27/2017', '12/03/2017', '12/09/2017',
#        '12/15/2017', '12/27/2017', '05/07/2017'], dtype=object)

# %% [markdown]
# ## Cleaning Functions
# [(back to top)](#Cleaning)
#
# Wrote and ran a function to "autpmate" the cleaning process and extract the most useful information so we can later add it to a single, larger data set.

# %%
def clean_cleaveland_air(df_in, col = ''):
    if((len(col) == 0) & (df_in.shape[1] > 4)):
        col = df_in.columns[4]
    col_rename = col.split(' ')[3].lower()
    col_meas = '_max'
    if(col_rename == 'concentration'):
        col_rename = col.split(' ')[2].lower()
        col_meas = '_mean'
    
    df_in.rename(columns={'Date':'date'}, inplace=True)
    df_out = df_in[['date', col, 'DAILY_AQI_VALUE']]#, 'Site Name']]
    df_out['date'] = pd.to_datetime(df_out['date'])
    df_out.set_index('date', inplace=True)
    
    df_out.rename(columns={
        col: col_rename + col_meas, 
        'DAILY_AQI_VALUE': col_rename + '_aqi_val'
#         , 'Site Name': 'site_name'
    }, inplace=True)
    
    print(f'\nSUM OF NaNs: {df_out.isna().sum().sum()}\n')
    return df_out

# %%
clean_no2 = clean_cleaveland_air(no2_gt1)#, 'Daily Max 1-hour NO2 Concentration')
clean_no2.head()
# Out:
# SUM OF NaNs: 0
#             no2_max  no2_aqi_val
# date
# 2017-01-01       36           34
# 2017-01-02       33           31
# 2017-01-03       24           23
# 2017-01-05       19           18
# 2017-01-06       25           24

# %%
clean_co = clean_cleaveland_air(co_gt1) #, 'Daily Max 8-hour CO Concentration')
clean_co.head()
# Out:
# SUM OF NaNs: 0
#             co_max  co_aqi_val
# date
# 2017-01-01     0.5           6
# 2017-01-02     0.5           6
# 2017-01-03     0.4           5
# 2017-01-04     0.2           2
# 2017-01-06     0.3           3

# %%
clean_o3 = clean_cleaveland_air(o3_gt1)
clean_o3.head()
# Out:
# SUM OF NaNs: 0
#             ozone_max  ozone_aqi_val
# date
# 2017-01-01      0.026             24
# 2017-01-02      0.009              8
# 2017-01-03      0.015             14
# 2017-01-04      0.027             25
# 2017-01-05      0.020             19

# %%
clean_pm10 = clean_cleaveland_air(pm10_gt3)
clean_pm10.head()
# Out:
# SUM OF NaNs: 0
#             pm10_mean  pm10_aqi_val
# date
# 2017-01-01         21            19
# 2017-01-02         18            17
# 2017-01-03          9             8
# 2017-01-04         19            18
# 2017-01-05         11            10

# %%
clean_pm25 = clean_cleaveland_air(pm25_gt3)
clean_pm25.head()
# Out:
# SUM OF NaNs: 0
#             pm2.5_mean  pm2.5_aqi_val
# date
# 2017-01-01         9.6             40
# 2017-01-02        14.1             55
# 2017-01-03         7.7             32
# 2017-01-04         4.6             19
# 2017-01-05         5.3             22

# %%
clean_so2 = clean_cleaveland_air(so2_gt1)
clean_so2.head()
# Out:
# SUM OF NaNs: 0
#             so2_max  so2_aqi_val
# date
# 2017-01-01      5.0            7
# 2017-01-02      2.0            3
# 2017-01-03      0.0            0
# 2017-01-04      0.0            0
# 2017-01-05      0.0            0

# %%
clean_no2_2018 = clean_cleaveland_air(no2_gt1_2018)
# Out:
# SUM OF NaNs: 0

# %%
clean_co_2018 = clean_cleaveland_air(co_gt1_2018)
# Out:
# SUM OF NaNs: 0

# %%
clean_o3_2018 = clean_cleaveland_air(o3_gt1_2018)
# Out:
# SUM OF NaNs: 0

# %%
clean_pm10_2018 = clean_cleaveland_air(pm10_gt3_2018)
# Out:
# SUM OF NaNs: 0

# %%
clean_pm25_2018 = clean_cleaveland_air(pm25_gt3_2018)
# Out:
# SUM OF NaNs: 0

# %%
clean_so2_2018 = clean_cleaveland_air(so2_gt1_2018)
# Out:
# SUM OF NaNs: 0

# %%
clean_no2_2019 = clean_cleaveland_air(no2_gt1_2019)
# Out:
# SUM OF NaNs: 0

# %%
clean_co_2019 = clean_cleaveland_air(co_gt1_2019)
# Out:
# SUM OF NaNs: 0

# %%
clean_o3_2019 = clean_cleaveland_air(o3_gt1_2019)
# Out:
# SUM OF NaNs: 0

# %%
clean_pm10_2019 = clean_cleaveland_air(pm10_gt3_2019)
# Out:
# SUM OF NaNs: 0

# %%
clean_pm25_2019 = clean_cleaveland_air(pm25_gt3_2019)
# Out:
# SUM OF NaNs: 0

# %%
clean_so2_2019 = clean_cleaveland_air(so2_gt1_2019)
# Out:
# SUM OF NaNs: 0

# %% [markdown]
# ## Merge Clean Data
# [(back to top)](#Cleaning)
#
# Here we took our 2017 data describing pollutants at "GT Craig NCore" and merged our cleaned and simplified data together and added temperature data to it.

# %%
clean_co.index.value_counts().sort_index()
# Out:
# 2017-01-01    1
# 2017-01-02    1
# 2017-01-03    1
# 2017-01-04    1
# 2017-01-06    1
#              ..
# 2017-12-27    1
# 2017-12-28    1
# 2017-12-29    1
# 2017-12-30    1
# 2017-12-31    1
# Name: date, Length: 341, dtype: int64

# %%
merge_df = pd.merge(
    left = clean_co,
    right = pd.merge(
        left = clean_no2,
        right = pd.merge(
            left = clean_o3, 
            right = pd.merge(
                left = clean_pm10, 
                right = pd.merge(
                    left = clean_pm25, 
                    right = clean_so2,
                    left_index=True,
                    right_index=True,
                    how='outer'
                ),
                left_index=True,
                right_index=True,
                how='outer'
            ),
            left_index=True,
            right_index=True,
            how='outer'
        ),
        left_index=True,
        right_index=True,
        how='outer'
    ),
    left_index=True,
    right_index=True,
    how='outer'
)
merge_df # .to_csv('20210511_all_aqi.csv')
# Out:
#             co_max  co_aqi_val  no2_max  no2_aqi_val  ozone_max  \
# date
# 2017-01-01     0.5         6.0     36.0         34.0      0.026
# 2017-01-02     0.5         6.0     33.0         31.0      0.009
# 2017-01-03     0.4         5.0     24.0         23.0      0.015
# 2017-01-04     0.2         2.0      NaN          NaN      0.027
# 2017-01-05     NaN         NaN     19.0         18.0      0.020
# ...            ...         ...      ...          ...        ...
# 2017-12-27     0.3         3.0     29.0         27.0      0.025
# 2017-12-28     0.3         3.0     31.0         29.0      0.019
# 2017-12-29     0.3         3.0     19.0         18.0      0.022
# 2017-12-30     0.2         2.0     16.0         15.0      0.032
# 2017-12-31     0.3         3.0     27.0         25.0        NaN
#
#             ozone_aqi_val  pm10_mean  pm10_aqi_val  pm2.5_mean  pm2.5_aqi_val  \
# date
# 2017-01-01           24.0       21.0          19.0         9.6           40.0
# 2017-01-02            8.0       18.0          17.0        14.1           55.0
# 2017-01-03           14.0        9.0           8.0         7.7           32.0
# 2017-01-04           25.0       19.0          18.0         4.6           19.0
# 2017-01-05           19.0       11.0          10.0         5.3           22.0
# ...                   ...        ...           ...         ...            ...
# 2017-12-27           23.0       10.0           9.0        12.1           51.0
# 2017-12-28           18.0       15.0          14.0        11.9           50.0
# 2017-12-29           20.0       14.0          13.0        15.8           59.0
# 2017-12-30           30.0        8.0           7.0        10.3           43.0
# 2017-12-31            NaN       12.0          11.0         4.4           18.0
#
#             so2_max  so2_aqi_val
# date
# 2017-01-01      5.0          7.0
# 2017-01-02      2.0          3.0
# 2017-01-03      0.0          0.0
# 2017-01-04      0.0          0.0
# 2017-01-05      0.0          0.0
# ...             ...          ...
# 2017-12-27      1.0          1.0
# 2017-12-28      2.0          3.0
# 2017-12-29      1.0          1.0
# 2017-12-30      0.0          0.0
# 2017-12-31      1.0          1.0
#
# [363 rows x 12 columns]

# %%
merge_df['cumulative_aqi'] = merge_df[['co_aqi_val', 'no2_aqi_val', 'ozone_aqi_val', 'pm10_aqi_val', 'pm2.5_aqi_val', 'so2_aqi_val']].max(axis=1)
merge_df.head()
# Out:
#             co_max  co_aqi_val  no2_max  no2_aqi_val  ozone_max  \
# date
# 2017-01-01     0.5         6.0     36.0         34.0      0.026
# 2017-01-02     0.5         6.0     33.0         31.0      0.009
# 2017-01-03     0.4         5.0     24.0         23.0      0.015
# 2017-01-04     0.2         2.0      NaN          NaN      0.027
# 2017-01-05     NaN         NaN     19.0         18.0      0.020
#
#             ozone_aqi_val  pm10_mean  pm10_aqi_val  pm2.5_mean  pm2.5_aqi_val  \
# date
# 2017-01-01           24.0       21.0          19.0         9.6           40.0
# 2017-01-02            8.0       18.0          17.0        14.1           55.0
# 2017-01-03           14.0        9.0           8.0         7.7           32.0
# 2017-01-04           25.0       19.0          18.0         4.6           19.0
# 2017-01-05           19.0       11.0          10.0         5.3           22.0
#
#             so2_max  so2_aqi_val  cumulative_aqi
# date
# 2017-01-01      5.0          7.0            40.0
# 2017-01-02      2.0          3.0            55.0
# 2017-01-03      0.0          0.0            32.0
# 2017-01-04      0.0          0.0            25.0
# 2017-01-05      0.0          0.0            22.0

# %%
temp = pd.read_csv('../data/ClevelandOHweather2017.csv')
temp
# Out:
#            Date  High  Low
# 0      1/1/2017    43   27
# 1      1/2/2017    50   34
# 2      1/3/2017    50   40
# 3      1/4/2017    40   20
# 4      1/5/2017    21   13
# ..          ...   ...  ...
# 360  12/27/2017    13    4
# 361  12/28/2017    18    7
# 362  12/29/2017    19   14
# 363  12/30/2017    18   14
# 364  12/31/2017    19    3
#
# [365 rows x 3 columns]

# %%
temp.rename(columns={'Date': 'date', 'High': 'temp_high', 'Low': 'temp_low'}, inplace=True)
temp
# Out:
#            date  temp_high  temp_low
# 0      1/1/2017         43        27
# 1      1/2/2017         50        34
# 2      1/3/2017         50        40
# 3      1/4/2017         40        20
# 4      1/5/2017         21        13
# ..          ...        ...       ...
# 360  12/27/2017         13         4
# 361  12/28/2017         18         7
# 362  12/29/2017         19        14
# 363  12/30/2017         18        14
# 364  12/31/2017         19         3
#
# [365 rows x 3 columns]

# %%
temp['date'] = pd.to_datetime(temp['date'])
temp['date'] = temp['date'].dt.strftime("%m/%d/%Y")
temp
# Out:
#            date  temp_high  temp_low
# 0    01/01/2017         43        27
# 1    01/02/2017         50        34
# 2    01/03/2017         50        40
# 3    01/04/2017         40        20
# 4    01/05/2017         21        13
# ..          ...        ...       ...
# 360  12/27/2017         13         4
# 361  12/28/2017         18         7
# 362  12/29/2017         19        14
# 363  12/30/2017         18        14
# 364  12/31/2017         19         3
#
# [365 rows x 3 columns]

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       365 non-null    object
#  1   temp_high  365 non-null    int64
#  2   temp_low   365 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 8.7+ KB

# %%
temp['date'] = pd.to_datetime(temp['date'])
temp['temp_high'] = pd.to_numeric(temp['temp_high'])
temp['temp_low'] = pd.to_numeric(temp['temp_low'])
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       365 non-null    datetime64[ns]
#  1   temp_high  365 non-null    int64
#  2   temp_low   365 non-null    int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 8.7 KB

# %%
temp['temp_avg'] = (temp['temp_high'] + temp['temp_low'])/2
temp
# Out:
#           date  temp_high  temp_low  temp_avg
# 0   2017-01-01         43        27      35.0
# 1   2017-01-02         50        34      42.0
# 2   2017-01-03         50        40      45.0
# 3   2017-01-04         40        20      30.0
# 4   2017-01-05         21        13      17.0
# ..         ...        ...       ...       ...
# 360 2017-12-27         13         4       8.5
# 361 2017-12-28         18         7      12.5
# 362 2017-12-29         19        14      16.5
# 363 2017-12-30         18        14      16.0
# 364 2017-12-31         19         3      11.0
#
# [365 rows x 4 columns]

# %%
merge_temp = pd.merge(left=merge_df, right=temp, how='left', on='date')
merge_temp
# Out:
#           date  co_max  co_aqi_val  no2_max  no2_aqi_val  ozone_max  \
# 0   2017-01-01     0.5         6.0     36.0         34.0      0.026
# 1   2017-01-02     0.5         6.0     33.0         31.0      0.009
# 2   2017-01-03     0.4         5.0     24.0         23.0      0.015
# 3   2017-01-04     0.2         2.0      NaN          NaN      0.027
# 4   2017-01-05     NaN         NaN     19.0         18.0      0.020
# ..         ...     ...         ...      ...          ...        ...
# 358 2017-12-27     0.3         3.0     29.0         27.0      0.025
# 359 2017-12-28     0.3         3.0     31.0         29.0      0.019
# 360 2017-12-29     0.3         3.0     19.0         18.0      0.022
# 361 2017-12-30     0.2         2.0     16.0         15.0      0.032
# 362 2017-12-31     0.3         3.0     27.0         25.0        NaN
#
#      ozone_aqi_val  pm10_mean  pm10_aqi_val  pm2.5_mean  pm2.5_aqi_val  \
# 0             24.0       21.0          19.0         9.6           40.0
# 1              8.0       18.0          17.0        14.1           55.0
# 2             14.0        9.0           8.0         7.7           32.0
# 3             25.0       19.0          18.0         4.6           19.0
# 4             19.0       11.0          10.0         5.3           22.0
# ..             ...        ...           ...         ...            ...
# 358           23.0       10.0           9.0        12.1           51.0
# 359           18.0       15.0          14.0        11.9           50.0
# 360           20.0       14.0          13.0        15.8           59.0
# 361           30.0        8.0           7.0        10.3           43.0
# 362            NaN       12.0          11.0         4.4           18.0
#
#      so2_max  so2_aqi_val  cumulative_aqi  temp_high  temp_low  temp_avg
# 0        5.0          7.0            40.0         43        27      35.0
# 1        2.0          3.0            55.0         50        34      42.0
# 2        0.0          0.0            32.0         50        40      45.0
# 3        0.0          0.0            25.0         40        20      30.0
# 4        0.0          0.0            22.0         21        13      17.0
# ..       ...          ...             ...        ...       ...       ...
# 358      1.0          1.0            51.0         13         4       8.5
# 359      2.0          3.0            50.0         18         7      12.5
# 360      1.0          1.0            59.0         19        14      16.5
# 361      0.0          0.0            43.0         18        14      16.0
# 362      1.0          1.0            25.0         19         3      11.0
#
# [363 rows x 17 columns]

# %% [markdown]
# ## More Data to Import
# [(back to top)](#Cleaning)
#
# Since we already had the data for pollutants for 2018 and 2019, we gathered temperature data and imported it here.

# %%
temp_2018 = pd.read_csv('../data/ClevelandOHweather2018.csv')
temp_2018
# Out:
#            Date  High  Low
# 0      1/1/2018    12    0
# 1      1/2/2018    14    5
# 2      1/3/2018    21    4
# 3      1/4/2018    19    4
# 4      1/5/2018    10   -2
# ..          ...   ...  ...
# 360  12/27/2018    52   32
# 361  12/28/2018    58   36
# 362  12/29/2018    36   33
# 363  12/30/2018    42   32
# 364  12/31/2018    62   34
#
# [365 rows x 3 columns]

# %%
temp_2018.rename(columns={'Date': 'date', 'High': 'temp_high', 'Low': 'temp_low'}, inplace=True)
temp_2018
# Out:
#            date  temp_high  temp_low
# 0      1/1/2018         12         0
# 1      1/2/2018         14         5
# 2      1/3/2018         21         4
# 3      1/4/2018         19         4
# 4      1/5/2018         10        -2
# ..          ...        ...       ...
# 360  12/27/2018         52        32
# 361  12/28/2018         58        36
# 362  12/29/2018         36        33
# 363  12/30/2018         42        32
# 364  12/31/2018         62        34
#
# [365 rows x 3 columns]

# %%
temp_2018['date'] = pd.to_datetime(temp_2018['date'])
temp_2018['date'] = temp_2018['date'].dt.strftime("%m/%d/%Y")
temp_2018
# Out:
#            date  temp_high  temp_low
# 0    01/01/2018         12         0
# 1    01/02/2018         14         5
# 2    01/03/2018         21         4
# 3    01/04/2018         19         4
# 4    01/05/2018         10        -2
# ..          ...        ...       ...
# 360  12/27/2018         52        32
# 361  12/28/2018         58        36
# 362  12/29/2018         36        33
# 363  12/30/2018         42        32
# 364  12/31/2018         62        34
#
# [365 rows x 3 columns]

# %%
temp_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       365 non-null    object
#  1   temp_high  365 non-null    int64
#  2   temp_low   365 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 8.7+ KB

# %%
temp_2018['date'] = pd.to_datetime(temp_2018['date'])
temp_2018['temp_high'] = pd.to_numeric(temp_2018['temp_high'])
temp_2018['temp_low'] = pd.to_numeric(temp_2018['temp_low'])
temp_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       365 non-null    datetime64[ns]
#  1   temp_high  365 non-null    int64
#  2   temp_low   365 non-null    int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 8.7 KB

# %%
temp_2018['temp_avg'] = (temp_2018['temp_high'] + temp_2018['temp_low'])/2
temp_2018
# Out:
#           date  temp_high  temp_low  temp_avg
# 0   2018-01-01         12         0       6.0
# 1   2018-01-02         14         5       9.5
# 2   2018-01-03         21         4      12.5
# 3   2018-01-04         19         4      11.5
# 4   2018-01-05         10        -2       4.0
# ..         ...        ...       ...       ...
# 360 2018-12-27         52        32      42.0
# 361 2018-12-28         58        36      47.0
# 362 2018-12-29         36        33      34.5
# 363 2018-12-30         42        32      37.0
# 364 2018-12-31         62        34      48.0
#
# [365 rows x 4 columns]

# %%
temp_2019 = pd.read_csv('../data/ClevelandOHweather2019.csv')
temp_2019
# Out:
#            Date  High  Low
# 0      1/1/2019    56   34
# 1      1/2/2019    41   32
# 2      1/3/2019    36   31
# 3      1/4/2019    51   32
# 4      1/5/2019    48   28
# ..          ...   ...  ...
# 360  12/27/2019    61   40
# 361  12/28/2019    48   36
# 362  12/29/2019    59   41
# 363  12/30/2019    61   38
# 364  12/31/2019    39   29
#
# [365 rows x 3 columns]

# %%
temp_2019.rename(columns={'Date': 'date', 'High': 'temp_high', 'Low': 'temp_low'}, inplace=True)
temp_2019
# Out:
#            date  temp_high  temp_low
# 0      1/1/2019         56        34
# 1      1/2/2019         41        32
# 2      1/3/2019         36        31
# 3      1/4/2019         51        32
# 4      1/5/2019         48        28
# ..          ...        ...       ...
# 360  12/27/2019         61        40
# 361  12/28/2019         48        36
# 362  12/29/2019         59        41
# 363  12/30/2019         61        38
# 364  12/31/2019         39        29
#
# [365 rows x 3 columns]

# %%
temp_2019['date'] = pd.to_datetime(temp_2019['date'])
temp_2019['date'] = temp_2019['date'].dt.strftime("%m/%d/%Y")
temp_2019
# Out:
#            date  temp_high  temp_low
# 0    01/01/2019         56        34
# 1    01/02/2019         41        32
# 2    01/03/2019         36        31
# 3    01/04/2019         51        32
# 4    01/05/2019         48        28
# ..          ...        ...       ...
# 360  12/27/2019         61        40
# 361  12/28/2019         48        36
# 362  12/29/2019         59        41
# 363  12/30/2019         61        38
# 364  12/31/2019         39        29
#
# [365 rows x 3 columns]

# %%
temp_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       365 non-null    object
#  1   temp_high  365 non-null    int64
#  2   temp_low   365 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 8.7+ KB

# %%
temp_2019['date'] = pd.to_datetime(temp_2019['date'])
temp_2019['temp_high'] = pd.to_numeric(temp_2019['temp_high'])
temp_2019['temp_low'] = pd.to_numeric(temp_2019['temp_low'])
temp_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       365 non-null    datetime64[ns]
#  1   temp_high  365 non-null    int64
#  2   temp_low   365 non-null    int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 8.7 KB

# %%
temp_2019['temp_avg'] = (temp_2019['temp_high'] + temp_2019['temp_low'])/2
temp_2019
# Out:
#           date  temp_high  temp_low  temp_avg
# 0   2019-01-01         56        34      45.0
# 1   2019-01-02         41        32      36.5
# 2   2019-01-03         36        31      33.5
# 3   2019-01-04         51        32      41.5
# 4   2019-01-05         48        28      38.0
# ..         ...        ...       ...       ...
# 360 2019-12-27         61        40      50.5
# 361 2019-12-28         48        36      42.0
# 362 2019-12-29         59        41      50.0
# 363 2019-12-30         61        38      49.5
# 364 2019-12-31         39        29      34.0
#
# [365 rows x 4 columns]

# %% [markdown]
# ## More Data to Merge
# [(back to top)](#Cleaning)
#
# Here we are merging our 2018 and 2019 data together into Data Frames

# %%
merge_df_2018 = pd.merge(
    left = clean_co_2018,
    right = pd.merge(
        left = clean_no2_2018,
        right = pd.merge(
            left = clean_o3_2018, 
            right = pd.merge(
                left = clean_pm10_2018, 
                right = pd.merge(
                    left = clean_pm25_2018, 
                    right = clean_so2_2018,
                    left_index=True,
                    right_index=True,
                    how='outer'
                ),
                left_index=True,
                right_index=True,
                how='outer'
            ),
            left_index=True,
            right_index=True,
            how='outer'
        ),
        left_index=True,
        right_index=True,
        how='outer'
    ),
    left_index=True,
    right_index=True,
    how='outer'
)
merge_df_2018 # .to_csv('20210511_all_aqi.csv')
# Out:
#             co_max  co_aqi_val  no2_max  no2_aqi_val  ozone_max  \
# date
# 2018-01-01     NaN         NaN     27.0         25.0      0.031
# 2018-01-02     0.2         2.0     14.0         13.0      0.032
# 2018-01-03     NaN         NaN     34.0         32.0      0.027
# 2018-01-04     0.2         2.0     14.0         13.0      0.034
# 2018-01-05     0.3         3.0     12.0         11.0      0.031
# ...            ...         ...      ...          ...        ...
# 2018-12-27     0.8         9.0     34.0         32.0      0.028
# 2018-12-28     0.5         6.0     22.0         21.0      0.021
# 2018-12-29     0.2         2.0     13.0         12.0      0.023
# 2018-12-30     0.2         2.0     17.0         16.0      0.026
# 2018-12-31     0.4         5.0     23.0         22.0        NaN
#
#             ozone_aqi_val  pm10_mean  pm10_aqi_val  pm2.5_mean  pm2.5_aqi_val  \
# date
# 2018-01-01           29.0       11.0          10.0        13.8           55.0
# 2018-01-02           30.0       17.0          16.0         6.8           28.0
# 2018-01-03           25.0       31.0          29.0        13.6           54.0
# 2018-01-04           31.0       14.0          13.0         2.8           12.0
# 2018-01-05           29.0       17.0          16.0         0.7            3.0
# ...                   ...        ...           ...         ...            ...
# 2018-12-27           26.0       34.0          31.0        22.0           72.0
# 2018-12-28           19.0       10.0           9.0         8.2           34.0
# 2018-12-29           21.0        5.0           5.0         8.2           34.0
# 2018-12-30           24.0        8.0           7.0        11.4           48.0
# 2018-12-31            NaN       14.0          13.0        13.3           54.0
#
#             so2_max  so2_aqi_val
# date
# 2018-01-01      0.0          0.0
# 2018-01-02      0.0          0.0
# 2018-01-03      3.0          4.0
# 2018-01-04      0.0          0.0
# 2018-01-05      0.0          0.0
# ...             ...          ...
# 2018-12-27      2.0          3.0
# 2018-12-28      1.0          1.0
# 2018-12-29      0.0          0.0
# 2018-12-30      0.0          0.0
# 2018-12-31      1.0          1.0
#
# [365 rows x 12 columns]

# %%
merge_df_2018['cumulative_aqi'] = merge_df_2018[['co_aqi_val', 'no2_aqi_val', 'ozone_aqi_val', 'pm10_aqi_val', 'pm2.5_aqi_val', 'so2_aqi_val']].max(axis=1)
merge_df_2018.head()
# Out:
#             co_max  co_aqi_val  no2_max  no2_aqi_val  ozone_max  \
# date
# 2018-01-01     NaN         NaN     27.0         25.0      0.031
# 2018-01-02     0.2         2.0     14.0         13.0      0.032
# 2018-01-03     NaN         NaN     34.0         32.0      0.027
# 2018-01-04     0.2         2.0     14.0         13.0      0.034
# 2018-01-05     0.3         3.0     12.0         11.0      0.031
#
#             ozone_aqi_val  pm10_mean  pm10_aqi_val  pm2.5_mean  pm2.5_aqi_val  \
# date
# 2018-01-01           29.0       11.0          10.0        13.8           55.0
# 2018-01-02           30.0       17.0          16.0         6.8           28.0
# 2018-01-03           25.0       31.0          29.0        13.6           54.0
# 2018-01-04           31.0       14.0          13.0         2.8           12.0
# 2018-01-05           29.0       17.0          16.0         0.7            3.0
#
#             so2_max  so2_aqi_val  cumulative_aqi
# date
# 2018-01-01      0.0          0.0            55.0
# 2018-01-02      0.0          0.0            30.0
# 2018-01-03      3.0          4.0            54.0
# 2018-01-04      0.0          0.0            31.0
# 2018-01-05      0.0          0.0            29.0

# %%
merge_df_2019 = pd.merge(
    left = clean_co_2019,
    right = pd.merge(
        left = clean_no2_2019,
        right = pd.merge(
            left = clean_o3_2019, 
            right = pd.merge(
                left = clean_pm10_2019, 
                right = pd.merge(
                    left = clean_pm25_2019, 
                    right = clean_so2_2019,
                    left_index=True,
                    right_index=True,
                    how='outer'
                ),
                left_index=True,
                right_index=True,
                how='outer'
            ),
            left_index=True,
            right_index=True,
            how='outer'
        ),
        left_index=True,
        right_index=True,
        how='outer'
    ),
    left_index=True,
    right_index=True,
    how='outer'
)
merge_df_2019 # .to_csv('20210511_all_aqi.csv')
# Out:
#             co_max  co_aqi_val  no2_max  no2_aqi_val  ozone_max  \
# date
# 2019-01-01     0.2         2.0     10.0          9.0      0.024
# 2019-01-02     0.3         3.0     18.0         17.0      0.022
# 2019-01-03     0.2         2.0     12.0         11.0      0.021
# 2019-01-04     0.7         8.0     34.0         32.0      0.017
# 2019-01-05     1.0        11.0     28.0         26.0      0.022
# ...            ...         ...      ...          ...        ...
# 2019-12-27     0.2         2.0      9.0          8.0      0.022
# 2019-12-28     0.4         5.0     24.0         23.0      0.016
# 2019-12-29     0.4         5.0     12.0         11.0      0.018
# 2019-12-30     0.3         3.0      4.0          4.0      0.027
# 2019-12-31     0.2         2.0      5.0          5.0        NaN
#
#             ozone_aqi_val  pm10_mean  pm10_aqi_val  pm2.5_mean  pm2.5_aqi_val  \
# date
# 2019-01-01           22.0        6.0           6.0         9.4           39.0
# 2019-01-02           20.0       12.0          11.0        13.9           55.0
# 2019-01-03           19.0       10.0           9.0        11.5           48.0
# 2019-01-04           16.0       35.0          32.0        19.0           66.0
# 2019-01-05           20.0       19.0          18.0        27.2           83.0
# ...                   ...        ...           ...         ...            ...
# 2019-12-27           20.0       14.0          13.0        11.3           47.0
# 2019-12-28           15.0       19.0          18.0        20.9           70.0
# 2019-12-29           17.0       20.0          19.0        13.7           54.0
# 2019-12-30           25.0        6.0           6.0         NaN            NaN
# 2019-12-31            NaN        7.0           6.0         2.0            8.0
#
#             so2_max  so2_aqi_val
# date
# 2019-01-01      0.0          0.0
# 2019-01-02      1.0          1.0
# 2019-01-03      0.0          0.0
# 2019-01-04      5.0          7.0
# 2019-01-05      3.0          4.0
# ...             ...          ...
# 2019-12-27      0.0          0.0
# 2019-12-28      1.0          1.0
# 2019-12-29      1.0          1.0
# 2019-12-30      1.0          1.0
# 2019-12-31      0.0          0.0
#
# [365 rows x 12 columns]

# %%
merge_df_2019['cumulative_aqi'] = merge_df_2019[['co_aqi_val', 'no2_aqi_val', 'ozone_aqi_val', 'pm10_aqi_val', 'pm2.5_aqi_val', 'so2_aqi_val']].max(axis=1)
merge_df_2019.head()
# Out:
#             co_max  co_aqi_val  no2_max  no2_aqi_val  ozone_max  \
# date
# 2019-01-01     0.2         2.0     10.0          9.0      0.024
# 2019-01-02     0.3         3.0     18.0         17.0      0.022
# 2019-01-03     0.2         2.0     12.0         11.0      0.021
# 2019-01-04     0.7         8.0     34.0         32.0      0.017
# 2019-01-05     1.0        11.0     28.0         26.0      0.022
#
#             ozone_aqi_val  pm10_mean  pm10_aqi_val  pm2.5_mean  pm2.5_aqi_val  \
# date
# 2019-01-01           22.0        6.0           6.0         9.4           39.0
# 2019-01-02           20.0       12.0          11.0        13.9           55.0
# 2019-01-03           19.0       10.0           9.0        11.5           48.0
# 2019-01-04           16.0       35.0          32.0        19.0           66.0
# 2019-01-05           20.0       19.0          18.0        27.2           83.0
#
#             so2_max  so2_aqi_val  cumulative_aqi
# date
# 2019-01-01      0.0          0.0            39.0
# 2019-01-02      1.0          1.0            55.0
# 2019-01-03      0.0          0.0            48.0
# 2019-01-04      5.0          7.0            66.0
# 2019-01-05      3.0          4.0            83.0

# %%
merge_temp_2018 = pd.merge(left=merge_df_2018, right=temp_2018, how='left', on='date')
merge_temp_2018
# Out:
#           date  co_max  co_aqi_val  no2_max  no2_aqi_val  ozone_max  \
# 0   2018-01-01     NaN         NaN     27.0         25.0      0.031
# 1   2018-01-02     0.2         2.0     14.0         13.0      0.032
# 2   2018-01-03     NaN         NaN     34.0         32.0      0.027
# 3   2018-01-04     0.2         2.0     14.0         13.0      0.034
# 4   2018-01-05     0.3         3.0     12.0         11.0      0.031
# ..         ...     ...         ...      ...          ...        ...
# 360 2018-12-27     0.8         9.0     34.0         32.0      0.028
# 361 2018-12-28     0.5         6.0     22.0         21.0      0.021
# 362 2018-12-29     0.2         2.0     13.0         12.0      0.023
# 363 2018-12-30     0.2         2.0     17.0         16.0      0.026
# 364 2018-12-31     0.4         5.0     23.0         22.0        NaN
#
#      ozone_aqi_val  pm10_mean  pm10_aqi_val  pm2.5_mean  pm2.5_aqi_val  \
# 0             29.0       11.0          10.0        13.8           55.0
# 1             30.0       17.0          16.0         6.8           28.0
# 2             25.0       31.0          29.0        13.6           54.0
# 3             31.0       14.0          13.0         2.8           12.0
# 4             29.0       17.0          16.0         0.7            3.0
# ..             ...        ...           ...         ...            ...
# 360           26.0       34.0          31.0        22.0           72.0
# 361           19.0       10.0           9.0         8.2           34.0
# 362           21.0        5.0           5.0         8.2           34.0
# 363           24.0        8.0           7.0        11.4           48.0
# 364            NaN       14.0          13.0        13.3           54.0
#
#      so2_max  so2_aqi_val  cumulative_aqi  temp_high  temp_low  temp_avg
# 0        0.0          0.0            55.0         12         0       6.0
# 1        0.0          0.0            30.0         14         5       9.5
# 2        3.0          4.0            54.0         21         4      12.5
# 3        0.0          0.0            31.0         19         4      11.5
# 4        0.0          0.0            29.0         10        -2       4.0
# ..       ...          ...             ...        ...       ...       ...
# 360      2.0          3.0            72.0         52        32      42.0
# 361      1.0          1.0            34.0         58        36      47.0
# 362      0.0          0.0            34.0         36        33      34.5
# 363      0.0          0.0            48.0         42        32      37.0
# 364      1.0          1.0            54.0         62        34      48.0
#
# [365 rows x 17 columns]

# %%
merge_temp_2019 = pd.merge(left=merge_df_2019, right=temp_2019, how='left', on='date')
merge_temp_2019
# Out:
#           date  co_max  co_aqi_val  no2_max  no2_aqi_val  ozone_max  \
# 0   2019-01-01     0.2         2.0     10.0          9.0      0.024
# 1   2019-01-02     0.3         3.0     18.0         17.0      0.022
# 2   2019-01-03     0.2         2.0     12.0         11.0      0.021
# 3   2019-01-04     0.7         8.0     34.0         32.0      0.017
# 4   2019-01-05     1.0        11.0     28.0         26.0      0.022
# ..         ...     ...         ...      ...          ...        ...
# 360 2019-12-27     0.2         2.0      9.0          8.0      0.022
# 361 2019-12-28     0.4         5.0     24.0         23.0      0.016
# 362 2019-12-29     0.4         5.0     12.0         11.0      0.018
# 363 2019-12-30     0.3         3.0      4.0          4.0      0.027
# 364 2019-12-31     0.2         2.0      5.0          5.0        NaN
#
#      ozone_aqi_val  pm10_mean  pm10_aqi_val  pm2.5_mean  pm2.5_aqi_val  \
# 0             22.0        6.0           6.0         9.4           39.0
# 1             20.0       12.0          11.0        13.9           55.0
# 2             19.0       10.0           9.0        11.5           48.0
# 3             16.0       35.0          32.0        19.0           66.0
# 4             20.0       19.0          18.0        27.2           83.0
# ..             ...        ...           ...         ...            ...
# 360           20.0       14.0          13.0        11.3           47.0
# 361           15.0       19.0          18.0        20.9           70.0
# 362           17.0       20.0          19.0        13.7           54.0
# 363           25.0        6.0           6.0         NaN            NaN
# 364            NaN        7.0           6.0         2.0            8.0
#
#      so2_max  so2_aqi_val  cumulative_aqi  temp_high  temp_low  temp_avg
# 0        0.0          0.0            39.0         56        34      45.0
# 1        1.0          1.0            55.0         41        32      36.5
# 2        0.0          0.0            48.0         36        31      33.5
# 3        5.0          7.0            66.0         51        32      41.5
# 4        3.0          4.0            83.0         48        28      38.0
# ..       ...          ...             ...        ...       ...       ...
# 360      0.0          0.0            47.0         61        40      50.5
# 361      1.0          1.0            70.0         48        36      42.0
# 362      1.0          1.0            54.0         59        41      50.0
# 363      1.0          1.0            25.0         61        38      49.5
# 364      0.0          0.0             8.0         39        29      34.0
#
# [365 rows x 17 columns]

# %% [markdown]
# ## Putting the years together
# [(back to top)](#Cleaning)
#
# Now that the data is all together, all six pollutants along with temperature observations, and their respective columns are named the same, we can merge all the data together into one Data Frame for export.

# %%
concat_df = pd.concat([merge_temp, merge_temp_2018, merge_temp_2019], axis=0, ignore_index=True)
concat_df
# Out:
#            date  co_max  co_aqi_val  no2_max  no2_aqi_val  ozone_max  \
# 0    2017-01-01     0.5         6.0     36.0         34.0      0.026
# 1    2017-01-02     0.5         6.0     33.0         31.0      0.009
# 2    2017-01-03     0.4         5.0     24.0         23.0      0.015
# 3    2017-01-04     0.2         2.0      NaN          NaN      0.027
# 4    2017-01-05     NaN         NaN     19.0         18.0      0.020
# ...         ...     ...         ...      ...          ...        ...
# 1088 2019-12-27     0.2         2.0      9.0          8.0      0.022
# 1089 2019-12-28     0.4         5.0     24.0         23.0      0.016
# 1090 2019-12-29     0.4         5.0     12.0         11.0      0.018
# 1091 2019-12-30     0.3         3.0      4.0          4.0      0.027
# 1092 2019-12-31     0.2         2.0      5.0          5.0        NaN
#
#       ozone_aqi_val  pm10_mean  pm10_aqi_val  pm2.5_mean  pm2.5_aqi_val  \
# 0              24.0       21.0          19.0         9.6           40.0
# 1               8.0       18.0          17.0        14.1           55.0
# 2              14.0        9.0           8.0         7.7           32.0
# 3              25.0       19.0          18.0         4.6           19.0
# 4              19.0       11.0          10.0         5.3           22.0
# ...             ...        ...           ...         ...            ...
# 1088           20.0       14.0          13.0        11.3           47.0
# 1089           15.0       19.0          18.0        20.9           70.0
# 1090           17.0       20.0          19.0        13.7           54.0
# 1091           25.0        6.0           6.0         NaN            NaN
# 1092            NaN        7.0           6.0         2.0            8.0
#
#       so2_max  so2_aqi_val  cumulative_aqi  temp_high  temp_low  temp_avg
# 0         5.0          7.0            40.0         43        27      35.0
# 1         2.0          3.0            55.0         50        34      42.0
# 2         0.0          0.0            32.0         50        40      45.0
# 3         0.0          0.0            25.0         40        20      30.0
# 4         0.0          0.0            22.0         21        13      17.0
# ...       ...          ...             ...        ...       ...       ...
# 1088      0.0          0.0            47.0         61        40      50.5
# 1089      1.0          1.0            70.0         48        36      42.0
# 1090      1.0          1.0            54.0         59        41      50.0
# 1091      1.0          1.0            25.0         61        38      49.5
# 1092      0.0          0.0             8.0         39        29      34.0
#
# [1093 rows x 17 columns]

# %% [markdown]
# ### Rename Columns
# [(back to top)](#Cleaning)

# %%
# 'high_temp', 'low_temp', 'co_max', 'co_aqi_val', 'no2_max', 'no2_aqi_val', 'ozone_max', 'ozone_aqi_val', 'pm10_mean', 
# 'pm10_aqi_val', 'pm2.5_mean', 'pm2.5_aqi_val', 'so2_max', 'so2_aqi_val', 'cumulitive_aqi', 'pct_change_aqi', 
# 'average_daily_temp', 'month', 'weekday'

concat_df.rename(columns={
    'date': 'date', 
    'co_max': 'co_max', 
    'co_aqi_val': 'co_aqi_val', 
    'no2_max': 'no2_max', 
    'no2_aqi_val': 'no2_aqi_val', 
    'ozone_max': 'ozone_max', 
    'ozone_aqi_val': 'ozone_aqi_val', 
    'pm10_mean': 'pm10_mean', 
    'pm10_aqi_val': 'pm10_aqi_val', 
    'pm2.5_mean': 'pm2.5_mean', 
    'pm2.5_aqi_val': 'pm2.5_aqi_val', 
    'so2_max': 'so2_max', 
    'so2_aqi_val': 'so2_aqi_val', 
    'cumulative_aqi': 'cumulitive_aqi', 
    'temp_high': 'high_temp', 
    'temp_low': 'low_temp', 
    'temp_avg':'average_daily_temp'
})
# Out:
#            date  co_max  co_aqi_val  no2_max  no2_aqi_val  ozone_max  \
# 0    2017-01-01     0.5         6.0     36.0         34.0      0.026
# 1    2017-01-02     0.5         6.0     33.0         31.0      0.009
# 2    2017-01-03     0.4         5.0     24.0         23.0      0.015
# 3    2017-01-04     0.2         2.0      NaN          NaN      0.027
# 4    2017-01-05     NaN         NaN     19.0         18.0      0.020
# ...         ...     ...         ...      ...          ...        ...
# 1088 2019-12-27     0.2         2.0      9.0          8.0      0.022
# 1089 2019-12-28     0.4         5.0     24.0         23.0      0.016
# 1090 2019-12-29     0.4         5.0     12.0         11.0      0.018
# 1091 2019-12-30     0.3         3.0      4.0          4.0      0.027
# 1092 2019-12-31     0.2         2.0      5.0          5.0        NaN
#
#       ozone_aqi_val  pm10_mean  pm10_aqi_val  pm2.5_mean  pm2.5_aqi_val  \
# 0              24.0       21.0          19.0         9.6           40.0
# 1               8.0       18.0          17.0        14.1           55.0
# 2              14.0        9.0           8.0         7.7           32.0
# 3              25.0       19.0          18.0         4.6           19.0
# 4              19.0       11.0          10.0         5.3           22.0
# ...             ...        ...           ...         ...            ...
# 1088           20.0       14.0          13.0        11.3           47.0
# 1089           15.0       19.0          18.0        20.9           70.0
# 1090           17.0       20.0          19.0        13.7           54.0
# 1091           25.0        6.0           6.0         NaN            NaN
# 1092            NaN        7.0           6.0         2.0            8.0
#
#       so2_max  so2_aqi_val  cumulitive_aqi  high_temp  low_temp  \
# 0         5.0          7.0            40.0         43        27
# 1         2.0          3.0            55.0         50        34
# 2         0.0          0.0            32.0         50        40
# 3         0.0          0.0            25.0         40        20
# 4         0.0          0.0            22.0         21        13
# ...       ...          ...             ...        ...       ...
# 1088      0.0          0.0            47.0         61        40
# 1089      1.0          1.0            70.0         48        36
# 1090      1.0          1.0            54.0         59        41
# 1091      1.0          1.0            25.0         61        38
# 1092      0.0          0.0             8.0         39        29
#
#       average_daily_temp
# 0                   35.0
# 1                   42.0
# 2                   45.0
# 3                   30.0
# 4                   17.0
# ...                  ...
# 1088                50.5
# 1089                42.0
# 1090                50.0
# 1091                49.5
# 1092                34.0
#
# [1093 rows x 17 columns]

# %% [markdown]
# ### Add Columns
# [(back to top)](#Cleaning)

# %%
concat_df['date'] = pd.to_datetime(concat_df['date'])

# %%
concat_df['pct_change_aqi'] = concat_df['cumulative_aqi'].pct_change()

# %%
concat_df['month'] = concat_df['date'].dt.month

# %%
concat_df['weekday'] = concat_df['date'].dt.dayofweek

# %%
concat_df
# Out:
#            date  co_max  co_aqi_val  no2_max  no2_aqi_val  ozone_max  \
# 0    2017-01-01     0.5         6.0     36.0         34.0      0.026
# 1    2017-01-02     0.5         6.0     33.0         31.0      0.009
# 2    2017-01-03     0.4         5.0     24.0         23.0      0.015
# 3    2017-01-04     0.2         2.0      NaN          NaN      0.027
# 4    2017-01-05     NaN         NaN     19.0         18.0      0.020
# ...         ...     ...         ...      ...          ...        ...
# 1088 2019-12-27     0.2         2.0      9.0          8.0      0.022
# 1089 2019-12-28     0.4         5.0     24.0         23.0      0.016
# 1090 2019-12-29     0.4         5.0     12.0         11.0      0.018
# 1091 2019-12-30     0.3         3.0      4.0          4.0      0.027
# 1092 2019-12-31     0.2         2.0      5.0          5.0        NaN
#
#       ozone_aqi_val  pm10_mean  pm10_aqi_val  pm2.5_mean  pm2.5_aqi_val  \
# 0              24.0       21.0          19.0         9.6           40.0
# 1               8.0       18.0          17.0        14.1           55.0
# 2              14.0        9.0           8.0         7.7           32.0
# 3              25.0       19.0          18.0         4.6           19.0
# 4              19.0       11.0          10.0         5.3           22.0
# ...             ...        ...           ...         ...            ...
# 1088           20.0       14.0          13.0        11.3           47.0
# 1089           15.0       19.0          18.0        20.9           70.0
# 1090           17.0       20.0          19.0        13.7           54.0
# 1091           25.0        6.0           6.0         NaN            NaN
# 1092            NaN        7.0           6.0         2.0            8.0
#
#       so2_max  so2_aqi_val  cumulative_aqi  temp_high  temp_low  temp_avg  \
# 0         5.0          7.0            40.0         43        27      35.0
# 1         2.0          3.0            55.0         50        34      42.0
# 2         0.0          0.0            32.0         50        40      45.0
# 3         0.0          0.0            25.0         40        20      30.0
# 4         0.0          0.0            22.0         21        13      17.0
# ...       ...          ...             ...        ...       ...       ...
# 1088      0.0          0.0            47.0         61        40      50.5
# 1089      1.0          1.0            70.0         48        36      42.0
# 1090      1.0          1.0            54.0         59        41      50.0
# 1091      1.0          1.0            25.0         61        38      49.5
# 1092      0.0          0.0             8.0         39        29      34.0
#
#       pct_change_aqi  month  weekday
# 0                NaN      1        6
# 1           0.375000      1        0
# 2          -0.418182      1        1
# 3          -0.218750      1        2
# 4          -0.120000      1        3
# ...              ...    ...      ...
# 1088        0.093023     12        4
# 1089        0.489362     12        5
# 1090       -0.228571     12        6
# 1091       -0.537037     12        0
# 1092       -0.680000     12        1
#
# [1093 rows x 20 columns]

# %% [markdown]
# ## Export Clean Data
# [(back to top)](#Cleaning)

# %%
output_file = '../data/cleaned_aqi_and_temp_data_2017-2019.csv'
concat_df.to_csv(output_file, index=False)
